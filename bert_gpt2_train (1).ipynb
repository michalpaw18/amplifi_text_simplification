# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2

# %%
# !ls
# Out:
# best_model    easse	    README.md	      sources.csv
# checkpoint    fkgl.py	    requirements.txt  tokenizer.py
# data.py       log_file.log  run.py	      wikilarge_detokenized
# dataset       output	    sari.py
# dataset_orig  __pycache__   source_preds.csv

# %%
# !git clone https://github.com/Aakash12980/Sentence-Simplification-using-BERT-GPT2

# %%
# !git clone https://github.com/feralvam/easse

# %%
# %cd easse 
# !pip install -e .
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2/easse
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2/easse
# ...
#   Cloning https://github.com/facebookresearch/text-simplification-evaluation.git (to revision main) to /tmp/pip-install-q20oq_p1/tseval_efcf5f21782b4f09b202662e05b8d222
#   Running command git clone -q https://github.com/facebookresearch/text-simplification-evaluation.git /tmp/pip-install-q20oq_p1/tseval_efcf5f21782b4f09b202662e05b8d222
# ...
#      |████████████████████████████████| 116 kB 15.4 MB/s
# ...
#      |████████████████████████████████| 880 kB 89.5 MB/s
# ...
#      |████████████████████████████████| 158 kB 68.8 MB/s
# ...
#      |████████████████████████████████| 60 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 181 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 78.3 MB/s
# ...

# %%
# %cd -
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2

# %%
# %cd /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2

# %%
# !ls
# Out:
# best_model    easse	    README.md	      sources.csv
# checkpoint    fkgl.py	    requirements.txt  tokenizer.py
# data.py       log_file.log  run.py	      wikilarge_detokenized
# dataset       output	    sari.py
# dataset_orig  __pycache__   source_preds.csv

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /D:/bld/cffi_1602537433319/work
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/D:/bld/cffi_1602537433319/work'

# %%
# !ls
# Out:
# best_model    easse	    README.md	      sources.csv
# checkpoint    fkgl.py	    requirements.txt  tokenizer.py
# data.py       log_file.log  run.py	      wikilarge_detokenized
# dataset       output	    sari.py
# dataset_orig  __pycache__   source_preds.csv

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import time
while True:
  time.sleep(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d0eca5c8e865> in <module>
#       1 import time
#       2 while True:
# ----> 3   time.sleep(0)
#
# KeyboardInterrupt:

# %%
# %cd /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2
# Out:
# /content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2

# %%
# !python run.py train --base_path "./" --src_train "dataset/src_train.txt"

# run.py train --base_path "./" --src_train "dataset/src_train.txt" --src_valid "dataset/src_valid.txt" /
#         --tgt_train "dataset/tgt_train.txt" --tgt_valid "dataset/tgt_valid.txt" /
#         --ref_valid "dataset/ref_valid.pkl" --checkpoint_path "checkpoint/model_ckpt.pt" /
#         --best_model "best_model/model.pt" --seed 540

# !python run.py train --base_path "./" --src_train "dataset/src_train.txt"
# !python run.py train 

# !python run.py train --base_path "./" --src_train "dataset/src_train.txt" --src_valid "dataset/src_valid.txt"  --tgt_train "dataset/tgt_train.txt" --ref_valid "dataset/ref_valid.pkl" --checkpoint_path "checkpoint/model_ckpt.pt"  --best_model "best_model/model.pt" --seed 540
# Out:
# Streaming output truncated to the last 5000 lines.
# In 1828 , Coenraad Johannes van Houten developed the first cocoa powder producing machine in the Netherlands .
# In 1828, Coenraad Johannes van Houten developed the first cocoa powder producing machine in the Netherlands.
# Progress in developing the TAR was hindered by political and economic obstacles throughout the 1960s , 1970s and early 1980s .
# Political and economic obstacles hindered the TAR's developmental progress throughout the 1960's, 1970's and early 1980's.
# After a version of a software package has remained in unstable for a certain length of time ( depending on the urgency of the software 's changes ) , that package is automatically migrated to the testing distribution .
# After a version of a software package has remained unsteady for sometime, that package is automatically moved to the testing distribution.
# ...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Sep  9 20:21:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# tgt_sent = []

# with open('/content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2/dataset/src_valid.txt') as f:
#   line2 = f.readlines()
#   for l in line2:
#     tgt_sent.append([l.strip()])

# # print(len(tgt_sent),len(tgt_sent[0]))
# pickle.dump(tgt_sent,open('/content/gdrive/MyDrive/baselines/bert_gpt2/bert_gpt2/dataset/ref_valid.pkl', 'wb'))

# %%
# !python run.py test
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !python run.py decode

# %%
from platform  import python_version

# %%
python_version()
# Out:
# '3.7.13'
